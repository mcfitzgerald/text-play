# %%
import utils.get_links as gl

# %%
url = "http://www.python.org"

# %%
source = gl.get_source(url)
# Out:
# end of page reached

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(source,'lxml')

# %%
for link in soup.find_all('a'):
    print(link)
# Out:
# <a href="#content" title="Skip to content">Skip to content</a>
# <a aria-hidden="true" class="jump-link" href="#python-network" id="close-python-network">
# <span aria-hidden="true" class="icon-arrow-down"><span>▼</span></span> Close
#                 </a>
# <a class="current_item selectedcurrent_branch selected" href="/" title="The Python Programming Language">Python</a>
# <a href="/psf-landing/" title="The Python Software Foundation">PSF</a>
# <a href="https://docs.python.org" title="Python Documentation">Docs</a>
# <a href="https://pypi.org/" title="Python Package Index">PyPI</a>
# <a href="/jobs/" title="Python Job Board">Jobs</a>
# <a href="/community-landing/">Community</a>
# <a aria-hidden="true" class="jump-link" href="#top" id="python-network">
# <span aria-hidden="true" class="icon-arrow-up"><span>▲</span></span> The Python Network
#                 </a>
# <a href="/"><img alt="python™" class="python-logo" height="72" src="/static/img/python-logo@2x.png" width="255"/></a>
# ...

# %%
url = "https://www.quora.com/search?q=systemic%20racism"

# %%
source = gl.get_source(url)
# Out:
# end of page reached

# %%
with open("source.html","w+") as f:
    f.write(source)

# %%
soup = BeautifulSoup(source,'lxml')

# %%
for link in soup.find_all('a',class_='qu-userSelect--text'):
    print(link.get('href'))
# Out:
# /
# /How-does-the-USA-have-systemic-racism
# /profile/Tom-Wetzel-4
# /profile/Tom-Wetzel-4
# /How-does-the-USA-have-systemic-racism/answers/117231049
# /What-are-some-examples-of-systemic-racism
# /profile/Dennis-Fischman
# /profile/Dennis-Fischman
# /What-are-some-examples-of-systemic-racism/answer/Dennis-Fischman
# /What-can-we-do-to-fight-systemic-racism
# /profile/Keilante-Taylor-2
# /profile/Keilante-Taylor-2
# /What-can-we-do-to-fight-systemic-racism/answer/Keilante-Taylor-2
# /What-is-institutional-or-systemic-racism
# /profile/Kevyn-Nightingale
# /profile/Kevyn-Nightingale
# /What-is-institutional-or-systemic-racism/answer/Kevyn-Nightingale
# /What-are-some-examples-of-institutional-racism
# /profile/Doug-Hensley-8
# /profile/Doug-Hensley-8
# /What-are-some-examples-of-institutional-racism/answer/Doug-Hensley-8
# /Where-is-the-proof-that-systemic-racism-exists
# /profile/Brad-Erickson-10
# /profile/Brad-Erickson-10
# ...
